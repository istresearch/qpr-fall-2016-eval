# %%
import json

# %%
ann_file = 'cluster_annotations.json'

with open(ann_file, 'r') as f:
    annotations = eval(f.read())

# %%
annotations[0]
# Out:
# [{'cluster_id': 207360,
#   'features': {'Phone Number': [{'label': 'Phone Number',
#      'text': '719/445/7775'}],
#    'Services': [{'label': 'Services', 'text': 'Qv/HH/H'}],
#    'Tattoos': [{'img': 'http://images2.backpage.com/imager/u/large/298107356/4e9bafbff933295b98f8893b725cd755.jpg',
#      'label': 'Tattoos'},
#     {'img': 'http://images1.backpage.com/imager/u/large/298107363/75bb2dc650b9e94283fe2ecb2516f7fb.jpg',
#      'label': 'Tattoos'},
#     {'img': 'http://images1.backpage.com/imager/u/large/298107577/d5769b9334f00819a714622a9a7a91d8.jpg',
#      'label': 'Tattoos'}],
#    'untagged': []},
#   'obj_parent': 'CB647F1F045F5DB4BB811E59F6AC83E59DBF6E24E02232EB425F00851252A332',
#   'relevant': 'yes'},
#  {'cluster_id': 207360,
#   'features': {'Name': [{'label': 'Name', 'text': 'Megan'}],
#    'Phone Number': [{'label': 'Phone Number', 'text': '719/445/7775'}],
#    'Services': [{'label': 'Services', 'text': 'quick/HH/h'}],
#    'untagged': []},
# ...
